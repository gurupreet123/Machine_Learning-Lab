# %% [markdown]
# <a href="https://colab.research.google.com/github/AyushGupte-22/Machine_Learning_Lab_120/blob/main/ML_Lab_Prac_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_absolute_error, mean_squared_error

# %%
X = np.array([[1],[2],[3],[4],[5]])  # hours studied
y = np.array([20,40,50,65,80])       # test scores

# %%
model = LinearRegression()
model.fit(X,y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X)

# %%
plt.scatter(X,y, color = 'blue', label="Actual Data")
plt.plot(X, y_pred, color='red', linewidth=2, label = "Regression Line")
plt.xlabel("Hours Studied")
plt.ylabel("Test Score")
plt.title("Linear Regression Model")
plt.xlabel("Hours Studied")
plt.ylabel("Test Score")
plt.legend()
plt.show()

# %%
mae = mean_absolute_error(y, y_pred)
mse = mean_squared_error(y, y_pred)
rmse = np.sqrt(mse)

# %%
print("Mean Absolute Error (MAE):", mae)
print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
# Out:
# Mean Absolute Error (MAE): 1.3999999999999992
# Mean Squared Error (MSE): 3.5000000000000013
# Root Mean Squared Error (RMSE): 1.870828693386971
